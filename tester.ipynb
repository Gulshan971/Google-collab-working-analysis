# %%
import pickle 
import numpy as np

# %%
ohe_sex = pickle.load(open('ohe_sex.pkl' , 'rb') )
ohe_embark = pickle.load(open('ohe_embark.pkl' , 'rb'))
dTC = pickle.load(open('dTC.pkl' , 'rb'))

# %% [markdown]
# 	Pclass	Sex	Age	SibSp	Parch	Fare	Embarked

# %%
list = [2,'female' , 58.9 , 3, 2 , 65.88338 , 'S'],

# %%
np.array(list).dtype
# Out:
# dtype('<U32')

# %%
test = np.array([2,'female' , 58.9 , 3, 2 , 65.88338 , 'S'], dtype = object)

# %%
test.shape
# Out:
# (7,)

# %%
t_i = test.reshape(1 ,7)

# %%
t_i.shape
# Out:
# (1, 7)

# %%
t_i
# Out:
# array([[2, 'female', 58.9, 3, 2, 65.88338, 'S']], dtype=object)

# %%
test_sex = ohe_sex.transform(t_i[: , 1].reshape(1,1))
# Out:
# c:\Users\gulshan\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_embark = ohe_embark.transform(t_i[: , -1].reshape(1,1))
# Out:
# c:\Users\gulshan\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_embark.shape
# Out:
# (1, 4)

# %%
test_age = t_i[:,2].reshape(1,1)

# %%
test_age
# Out:
# array([[58.9]], dtype=object)

# %%
test_transform = np.concatenate((t_i[: , [0,3,4,5]], test_age , test_sex ,test_embark) , axis = 1)

# %%
test_transform.shape
# Out:
# (1, 11)

# %%
dTC.predict(test_transform)
# Out:
# array([1])

# %%
dTC.predict_proba(test_transform)
# Out:
# array([[0., 1.]])

# %%
dTC.predict_log_proba(test_transform)
# Out:
# c:\Users\gulshan\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\tree\_classes.py:1092: RuntimeWarning: divide by zero encountered in log
#   return np.log(proba)
# array([[-inf,   0.]])

# %% [markdown]
# Conclusion  : Means that our patient would surive
