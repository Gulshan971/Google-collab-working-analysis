# %%
import numpy as np 
import pickle

# %%
pipe = pickle.load(open('pipe.pkl' , 'rb'))

# %%
test_input = test = np.array([2,'female' , 58.9 , 3, 2 , 65.88338 , 'S'], dtype = object).reshape(1,7)

# %%
pipe.predict(test)
# Out:
# c:\Users\gulshan\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\gulshan\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])

# %%
# Conclusion

# %% [markdown]
# Automation makes it dead , Contrasting with what manual way did....
